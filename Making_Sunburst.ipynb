# %% [markdown]
# **Authors**: <br>
#     Iryna Savchuk | 20211310 <br>
#     Cátia Parrinha | 20201320 <br>

# %%
import pandas as pd
import numpy as np

import plotly.graph_objects as go
import plotly.express as px

# %%
df = pd.read_csv('data/merged.csv')

# %% [markdown]
# Add a new column with 'count' with 1 to have the total of awards count

# %%
#df['count'] = 1
df['total'] = df.shape[0]
df.head(2)
# Out:
#    id       firstname  surname  born  died            bornCountry  \
# 0   1  Wilhelm Conrad  Röntgen  1845  1923  Prussia (now Germany)
# 1   2      Hendrik A.  Lorentz  1853  1928        the Netherlands
#
#   bornCountryCode                bornCity      diedCountry diedCountryCode  \
# 0              DE  Lennep (now Remscheid)          Germany              DE
# 1              NL                  Arnhem  the Netherlands              NL
#
#    ...  year category  overallMotivation share  \
# 0  ...  1901  physics                NaN     1
# 1  ...  1902  physics                NaN     2
#
#                                           motivation               name  \
# 0  "in recognition of the extraordinary services ...  Munich University
# 1  "in recognition of the extraordinary service t...  Leiden University
#
#      city          country prizeAge total
# 0  Munich          Germany       56   989
# 1  Leiden  the Netherlands       49   989
#
# [2 rows x 22 columns]

# %%
df.shape
# Out:
# (989, 22)

# %%
sunburst_df =  df.groupby(['total','category', 'gender'], as_index=False).size()
sunburst_df
# Out:
#     total    category  gender  size
# 0     989   chemistry  female     8
# 1     989   chemistry    male   183
# 2     989   economics  female     2
# 3     989   economics    male    90
# 4     989  literature  female    17
# 5     989  literature    male   102
# 6     989    medicine  female    12
# 7     989    medicine    male   213
# 8     989       peace  female    18
# 9     989       peace    male    92
# 10    989       peace     org    30
# 11    989     physics  female     4
# 12    989     physics    male   218

# %%
fig_test = px.sunburst(sunburst_df, path=['total', 'category', 'gender'], 
                       values='size')

fig_test.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="33bcbc8f-2226-4bd4-85dd-136f1122f110" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33bcbc8f-2226-4bd4-85dd-136f1122f110")) {                    Plotly.newPlot(                        "33bcbc8f-2226-4bd4-85dd-136f1122f110",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>size=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["989/chemistry/female","989/economics/female","989/literature/female","989/medicine/female","989/peace/female","989/physics/female","989/chemistry/male","989/economics/male","989/literature/male","989/medicine/male","989/peace/male","989/physics/male","989/peace/org","989/chemistry","989/economics","989/literature","989/medicine","989/peace","989/physics","989"],"labels":["female","female","female","female","female","female","male","male","male","male","male","male","org","chemistry","economics","literature","medicine","peace","physics","989"],"name":"","parents":["989/chemistry","989/economics","989/literature","989/medicine","989/peace","989/physics","989/chemistry","989/economics","989/literature","989/medicine","989/peace","989/physics","989/peace","989","989","989","989","989","989",""],"values":[8,2,17,12,18,4,183,90,102,213,92,218,30,191,92,119,225,140,222,989],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778," ...

# %% [markdown]
# ### Building Sunburst Digram (combining Males and Females into PERSON)

# %%
sunburst_df =  df.groupby(['total','category', 'gender'], as_index=False).size()
sunburst_df['total'] =  '989 Laureates' #str(df.shape[0]) + ' Laureates'
sunburst_df['laureate'] = sunburst_df['gender'].apply(lambda x: 'Organisation' if x=='org' else 'Individual')
sunburst_df['category'] = sunburst_df['category'].apply(lambda x: x.capitalize())
sunburst_df
# Out:
#             total    category  gender  size      laureate
# 0   989 Laureates   Chemistry  female     8    Individual
# 1   989 Laureates   Chemistry    male   183    Individual
# 2   989 Laureates   Economics  female     2    Individual
# 3   989 Laureates   Economics    male    90    Individual
# 4   989 Laureates  Literature  female    17    Individual
# 5   989 Laureates  Literature    male   102    Individual
# 6   989 Laureates    Medicine  female    12    Individual
# 7   989 Laureates    Medicine    male   213    Individual
# 8   989 Laureates       Peace  female    18    Individual
# 9   989 Laureates       Peace    male    92    Individual
# 10  989 Laureates       Peace     org    30  Organisation
# 11  989 Laureates     Physics  female     4    Individual
# 12  989 Laureates     Physics    male   218    Individual

# %%
fig_sunburst = px.sunburst(sunburst_df, 
                          path=['total', 'laureate', 'category'], 
                          #path=['laureate', 'category'], 
                          values='size',
                          color = 'laureate',
                          title="TWO laureate types - SIX award categories",
                          )
fig_sunburst.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d3b7ac68-736f-4c4c-96e5-f305909e32c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3b7ac68-736f-4c4c-96e5-f305909e32c6")) {                    Plotly.newPlot(                        "d3b7ac68-736f-4c4c-96e5-f305909e32c6",                        [{"branchvalues":"total","customdata":[["Individual"],["Individual"],["Individual"],["Individual"],["Individual"],["Organisation"],["Individual"],["Individual"],["Organisation"],["(?)"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>size=%{value}<br>parent=%{parent}<br>id=%{id}<br>laureate=%{customdata[0]}<extra></extra>","ids":["989 Laureates/Individual/Chemistry","989 Laureates/Individual/Economics","989 Laureates/Individual/Literature","989 Laureates/Individual/Medicine","989 Laureates/Individual/Peace","989 Laureates/Organisation/Peace","989 Laureates/Individual/Physics","989 Laureates/Individual","989 Laureates/Organisation","989 Laureates"],"labels":["Chemistry","Economics","Literature","Medicine","Peace","Peace","Physics","Individual","Organisation","989 Laureates"],"marker":{"colors":["#636efa","#636efa","#636efa","#636efa","#636efa","#EF553B","#636efa","#636efa","#EF553B","#00cc96"]},"name":"","parents":["989 Laureates/Individual","989 Laureates/Individual","989 Laureates/Individual","989 Laureates/Individual","989 Laureates/Individual","989 Laureates/Organisation","989 Laureates/Individual","989 Laureates","989 Laureates",""],"values":[191,92,119,225,110,30,222,959,30,989],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#4603 ...

# %%
print(fig_sunburst.data[0])
# Out:
# Sunburst({
#     'branchvalues': 'total',
#     'customdata': array([['Individual'],
#                          ['Individual'],
#                          ['Individual'],
#                          ['Individual'],
#                          ['Individual'],
#                          ['Organisation'],
#                          ['Individual'],
#                          ['Individual'],
#                          ['Organisation'],
#                          ['(?)']], dtype=object),
#     'domain': {'x': [0.0, 1.0], 'y': [0.0, 1.0]},
#     'hovertemplate': ('labels=%{label}<br>size=%{valu' ... '{customdata[0]}<extra></extra>'),
#     'ids': array(['989 Laureates/Individual/Chemistry',
#                   '989 Laureates/Individual/Economics',
#                   '989 Laureates/Individual/Literature',
#                   '989 Laureates/Individual/Medicine', '989 Laureates/Individual/Peace',
#                   '989 Laureates/Organisation/Peace', '989 Laureates/Individual/Physics',
#                   '989 Laureates/Individual', '989 Laureates/Organisation',
#                   '989 Laureates'], dtype=object),
#     'labels': array(['Chemistry', 'Economics', 'Literature', 'Medicine', 'Peace', 'Peace',
#                      'Physics', 'Individual', 'Organisation', '989 Laureates'], dtype=object),
#     'marker': {'colors': [#636efa, #636efa, #636efa, #636efa, #636efa, #EF553B,
#                           #636efa, #636efa, #EF553B, #00cc96]},
#     'name': '',
#     'parents': array(['989 Laureates/Individual', '989 Laureates/Individual',
#                       '989 Laureates/Individual', '989 Laureates/Individual',
#                       '989 Laureates/Individual', '989 Laureates/Organisation',
#                       '989 Laureates/Individual', '989 Laureates', '989 Laureates', ''],
#                      dtype=object),
#     'values': array([191,  92, 119, 225, 110,  30, 222, 959,  30, 989])
# })

# %%
print(fig_sunburst.data[0]['hovertemplate'])
# Out:
# labels=%{label}<br>size=%{value}<br>parent=%{parent}<br>id=%{id}<br>laureate=%{customdata[0]}<extra></extra>

# %%
fig_sunburst = px.sunburst(sunburst_df, 
                           path=['total', 'laureate', 'category'],  
                           #path=['laureate', 'category'], 
                           values='size',
                           color = 'laureate',
                           color_discrete_map={'(?)':'', 'Individual':'gold', 'Organisation':'blue'},
                           title="TWO laureate types - SIX award categories",
                          )

fig_sunburst.update_traces(hovertemplate="<b>%{label}:</b><br>%{value} Laureates<extra></extra>")
#fig_sunburst.update_traces(insidetextorientation='horizontal')
#fig_sunburst.update_traces(insidetextfont_size=14)
fig_sunburst.update_traces(leaf_opacity=0.55)
fig_sunburst.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="68012f03-c868-420a-a45d-79944e32d8bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68012f03-c868-420a-a45d-79944e32d8bc")) {                    Plotly.newPlot(                        "68012f03-c868-420a-a45d-79944e32d8bc",                        [{"branchvalues":"total","customdata":[["Individual"],["Individual"],["Individual"],["Individual"],["Individual"],["Organisation"],["Individual"],["Individual"],["Organisation"],["(?)"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"<b>%{label}:</b><br>%{value} Laureates<extra></extra>","ids":["989 Laureates/Individual/Chemistry","989 Laureates/Individual/Economics","989 Laureates/Individual/Literature","989 Laureates/Individual/Medicine","989 Laureates/Individual/Peace","989 Laureates/Organisation/Peace","989 Laureates/Individual/Physics","989 Laureates/Individual","989 Laureates/Organisation","989 Laureates"],"labels":["Chemistry","Economics","Literature","Medicine","Peace","Peace","Physics","Individual","Organisation","989 Laureates"],"marker":{"colors":["gold","gold","gold","gold","gold","blue","gold","gold","blue",""]},"name":"","parents":["989 Laureates/Individual","989 Laureates/Individual","989 Laureates/Individual","989 Laureates/Individual","989 Laureates/Individual","989 Laureates/Organisation","989 Laureates/Individual","989 Laureates","989 Laureates",""],"values":[191,92,119,225,110,30,222,959,30,989],"type":"sunburst","leaf":{"opacity":0.55}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e" ...

# %%
for i in fig_sunburst['data']:
  print(i)
# Out:
# Sunburst({
#     'branchvalues': 'total',
#     'customdata': array([['Individual'],
#                          ['Individual'],
#                          ['Individual'],
#                          ['Individual'],
#                          ['Individual'],
#                          ['Organisation'],
#                          ['Individual'],
#                          ['Individual'],
#                          ['Organisation'],
#                          ['(?)']], dtype=object),
#     'domain': {'x': [0.0, 1.0], 'y': [0.0, 1.0]},
#     'hovertemplate': '<b>%{label}:</b><br>%{value} Laureates<extra></extra>',
#     'ids': array(['989 Laureates/Individual/Chemistry',
#                   '989 Laureates/Individual/Economics',
#                   '989 Laureates/Individual/Literature',
#                   '989 Laureates/Individual/Medicine', '989 Laureates/Individual/Peace',
#                   '989 Laureates/Organisation/Peace', '989 Laureates/Individual/Physics',
#                   '989 Laureates/Individual', '989 Laureates/Organisation',
#                   '989 Laureates'], dtype=object),
#     'labels': array(['Chemistry', 'Economics', 'Literature', 'Medicine', 'Peace', 'Peace',
#                      'Physics', 'Individual', 'Organisation', '989 Laureates'], dtype=object),
#     'leaf': {'opacity': 0.55},
#     'marker': {'colors': ['gold', 'gold', 'gold', 'gold', 'gold', 'blue', 'gold', 'gold', 'blue', '']},
#     'name': '',
#     'parents': array(['989 Laureates/Individual', '989 Laureates/Individual',
#                       '989 Laureates/Individual', '989 Laureates/Individual',
#                       '989 Laureates/Individual', '989 Laureates/Organisation',
#                       '989 Laureates/Individual', '989 Laureates', '989 Laureates', ''],
#                      dtype=object),
#     'values': array([191,  92, 119, 225, 110,  30, 222, 959,  30, 989])
# })
