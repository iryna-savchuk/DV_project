# %% [markdown]
# # 1. Import Libraries

# %%
import requests
import io
import pandas as pd
import plotly.graph_objects as go

# %% [markdown]
# # 2. Import DataSets

# %% [markdown]
# Import, from the the sorce 'https://nobelprize.readme.io/reference/getting-started' the Nobel Prize dataset

# %%
#url_prizes = "http://api.nobelprize.org/v1/prize.csv"
url_laureate = "http://api.nobelprize.org/v1/laureate.csv?gender=All"
#url_country = "http://api.nobelprize.org/v1/country.csv"

#prize = requests.get(url_prizes).content
laureate = requests.get(url_laureate).content
#country = requests.get(url_country).content

#prize_df = pd.read_csv(io.StringIO(prize.decode('utf-8')))
laureate_df =  pd.read_csv(io.StringIO(laureate.decode('utf-8')))
#country_df =  pd.read_csv(io.StringIO(country.decode('utf-8')))

# %%
laureate_df.head()
# Out:
#    id       firstname    surname        born        died  \
# 0   1  Wilhelm Conrad    Röntgen  1845-03-27  1923-02-10
# 1   2      Hendrik A.    Lorentz  1853-07-18  1928-02-04
# 2   3          Pieter     Zeeman  1865-05-25  1943-10-09
# 3   4           Henri  Becquerel  1852-12-15  1908-08-25
# 4   5          Pierre      Curie  1859-05-15  1906-04-19
#
#              bornCountry bornCountryCode                bornCity  \
# 0  Prussia (now Germany)              DE  Lennep (now Remscheid)
# 1        the Netherlands              NL                  Arnhem
# 2        the Netherlands              NL              Zonnemaire
# 3                 France              FR                   Paris
# 4                 France              FR                   Paris
#
#        diedCountry diedCountryCode   diedCity gender  year category  \
# 0          Germany              DE     Munich   male  1901  physics
# 1  the Netherlands              NL        NaN   male  1902  physics
# 2  the Netherlands              NL  Amsterdam   male  1902  physics
# 3           France              FR        NaN   male  1903  physics
# 4           France              FR      Paris   male  1903  physics
#
#   overallMotivation  share                                         motivation  \
# 0               NaN      1  "in recognition of the extraordinary services ...
# 1               NaN      2  "in recognition of the extraordinary service t...
# 2               NaN      2  "in recognition of the extraordinary service t...
# 3               NaN      2  "in recognition of the extraordinary services ...
# 4               NaN      4  "in recognition of the extraordinary services ...
#
#                                                 name       city  \
# 0                                  Munich University     Munich
# 1                                  Leiden University     Leiden
# 2                               Amsterdam University  Amsterdam
# 3                                École Polytechnique      Paris
# 4  École municipale de physique et de chimie indu...      Paris
#
#            country
# 0          Germany
# 1  the Netherlands
# 2  the Netherlands
# 3           France
# 4           France

# %%
laureate_df.shape
# Out:
# (989, 20)

# %%
laureate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 989 entries, 0 to 988
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 989 non-null    int64
#  1   firstname          988 non-null    object
#  2   surname            956 non-null    object
#  3   born               988 non-null    object
#  4   died               989 non-null    object
#  5   bornCountry        958 non-null    object
#  6   bornCountryCode    958 non-null    object
#  7   bornCity           956 non-null    object
#  8   diedCountry        646 non-null    object
#  9   diedCountryCode    646 non-null    object
#  10  diedCity           640 non-null    object
#  11  gender             989 non-null    object
#  12  year               989 non-null    int64
#  13  category           989 non-null    object
#  14  overallMotivation  23 non-null     object
#  15  share              989 non-null    int64
#  16  motivation         989 non-null    object
#  17  name               727 non-null    object
#  18  city               722 non-null    object
#  19  country            724 non-null    object
# dtypes: int64(3), object(17)
# memory usage: 154.7+ KB

# %% [markdown]
# Import from kaggle additional information about the prize amount

# %%
#!pip install kaggle
#!kaggle datasets download -d imdevskp/nobel-prize
#!unzip nobel-prize.zip
# Out:
# Collecting kaggle
#   Downloading kaggle-1.5.13.tar.gz (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: python-dateutil in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle) (2.27.1)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle) (4.64.0)
# Collecting python-slugify
#   Downloading python_slugify-8.0.1-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: urllib3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle) (1.26.9)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->kaggle) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->kaggle) (3.3)
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.13-py3-none-any.whl size=77717 sha256=b4ad8df13aba8ef293b9c3d26669efd7bad015e33ee10aea9547fc1f738118f6
#   Stored in directory: /Users/iryna/Library/Caches/pip/wheels/f3/16/ff/34e7d368370d4fd68bb749a59f1d2639ed66f3c14358e340a1
# Successfully built kaggle
# Installing collected packages: text-unidecode, python-slugify, kaggle
# Successfully installed kaggle-1.5.13 python-slugify-8.0.1 text-unidecode-1.3
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/kaggle/api/kaggle_api_extended.py", line 164, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /Users/iryna/.kaggle. Or use the environment method.
# unzip:  cannot find or open nobel-prize.zip, nobel-prize.zip.zip or nobel-prize.zip.ZIP.

# %%
# !pip3 install opendatasets
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: kaggle in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opendatasets) (1.5.13)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opendatasets) (4.64.0)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opendatasets) (8.1.3)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle->opendatasets) (2021.10.8)
# Requirement already satisfied: python-dateutil in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: python-slugify in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle->opendatasets) (8.0.1)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle->opendatasets) (2.27.1)
# Requirement already satisfied: urllib3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle->opendatasets) (1.26.9)
# Requirement already satisfied: six>=1.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->kaggle->opendatasets) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->kaggle->opendatasets) (3.3)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22

# %%
#!pip3 install opendatasets 
import opendatasets as od

# %%
od.download(

# %%
prize_amount_df = pd.read_csv('complete.csv')

# %%
prize_amount_df.head()
# Out:
#    awardYear           category  \
# 0       2001  Economic Sciences
# 1       1975            Physics
# 2       2004          Chemistry
# 3       1982          Chemistry
# 4       1979            Physics
#
#                                     categoryFullName  sortOrder portion  \
# 0  The Sveriges Riksbank Prize in Economic Scienc...          2     1/3
# 1                         The Nobel Prize in Physics          1     1/3
# 2                       The Nobel Prize in Chemistry          1     1/3
# 3                       The Nobel Prize in Chemistry          1       1
# 4                         The Nobel Prize in Physics          2     1/3
#
#    prizeAmount  prizeAmountAdjusted dateAwarded prizeStatus  \
# 0     10000000             12295082  2001-10-10    received
# 1       630000              3404179  1975-10-17    received
# 2     10000000             11762861  2004-10-06    received
# 3      1150000              3102518  1982-10-18    received
# 4       800000              2988048  1979-10-15    received
#
#                                           motivation  ... org_founded_country  \
# 0  for their analyses of markets with asymmetric ...  ...                 NaN
# 1  for the discovery of the connection between co...  ...                 NaN
# 2  for the discovery of ubiquitin-mediated protei...  ...                 NaN
# 3  for his development of crystallographic electr...  ...                 NaN
# 4  for their contributions to the theory of the u...  ...                 NaN
#
#   org_founded_countryNow  org_founded_locationString  ind_or_org residence_1  \
# 0                    NaN                         NaN  Individual         NaN
# 1                    NaN                         NaN  Individual         NaN
# 2                    NaN                         NaN  Individual         NaN
# 3                    NaN                         NaN  Individual         NaN
# 4                    NaN                         NaN  Individual         NaN
#
#   residence_2                                      affiliation_1  \
# 0         NaN             Stanford University, Stanford, CA, USA
# 1         NaN          Niels Bohr Institute, Copenhagen, Denmark
# 2         NaN  Technion - Israel Institute of Technology, Hai...
# 3         NaN  MRC Laboratory of Molecular Biology, Cambridge...
# 4         NaN  International Centre for Theoretical Physics, ...
#
#                               affiliation_2 affiliation_3 affiliation_4
# 0                                       NaN           NaN           NaN
# 1                                       NaN           NaN           NaN
# 2                                       NaN           NaN           NaN
# 3                                       NaN           NaN           NaN
# 4  Imperial College, London, United Kingdom           NaN           NaN
#
# [5 rows x 52 columns]

# %%
columns_name = prize_amount_df.columns.tolist()
columns_name
# Out:
# ['awardYear',
#  'category',
#  'categoryFullName',
#  'sortOrder',
#  'portion',
#  'prizeAmount',
#  'prizeAmountAdjusted',
#  'dateAwarded',
#  'prizeStatus',
#  'motivation',
#  'categoryTopMotivation',
#  'award_link',
#  'id',
#  'name',
#  'knownName',
#  'givenName',
#  'familyName',
#  'fullName',
#  'penName',
#  'gender',
#  'laureate_link',
#  'birth_date',
#  'birth_city',
#  'birth_cityNow',
#  'birth_continent',
#  'birth_country',
#  'birth_countryNow',
#  'birth_locationString',
#  'death_date',
#  'death_city',
#  'death_cityNow',
#  'death_continent',
#  'death_country',
#  'death_countryNow',
#  'death_locationString',
#  'orgName',
#  'nativeName',
#  'acronym',
#  'org_founded_date',
#  'org_founded_city',
#  'org_founded_cityNow',
#  'org_founded_continent',
#  'org_founded_country',
#  'org_founded_countryNow',
#  'org_founded_locationString',
#  'ind_or_org',
#  'residence_1',
#  'residence_2',
#  'affiliation_1',
#  'affiliation_2',
#  'affiliation_3',
#  'affiliation_4']

# %%
# Add 'prizeAmount' and 'prizeAmountAdjusted' to 
df_merged = pd.merge(laureate_df, prize_amount_df[['id', 'prizeAmount', 'prizeAmountAdjusted']], on = 'id', how = 'left')
df_merged.head()
# Out:
#    id       firstname    surname        born        died  \
# 0   1  Wilhelm Conrad    Röntgen  1845-03-27  1923-02-10
# 1   2      Hendrik A.    Lorentz  1853-07-18  1928-02-04
# 2   3          Pieter     Zeeman  1865-05-25  1943-10-09
# 3   4           Henri  Becquerel  1852-12-15  1908-08-25
# 4   5          Pierre      Curie  1859-05-15  1906-04-19
#
#              bornCountry bornCountryCode                bornCity  \
# 0  Prussia (now Germany)              DE  Lennep (now Remscheid)
# 1        the Netherlands              NL                  Arnhem
# 2        the Netherlands              NL              Zonnemaire
# 3                 France              FR                   Paris
# 4                 France              FR                   Paris
#
#        diedCountry diedCountryCode  ...  year category  overallMotivation  \
# 0          Germany              DE  ...  1901  physics                NaN
# 1  the Netherlands              NL  ...  1902  physics                NaN
# 2  the Netherlands              NL  ...  1902  physics                NaN
# 3           France              FR  ...  1903  physics                NaN
# 4           France              FR  ...  1903  physics                NaN
#
#   share                                         motivation  \
# 0     1  "in recognition of the extraordinary services ...
# 1     2  "in recognition of the extraordinary service t...
# 2     2  "in recognition of the extraordinary service t...
# 3     2  "in recognition of the extraordinary services ...
# 4     4  "in recognition of the extraordinary services ...
#
#                                                 name       city  \
# 0                                  Munich University     Munich
# 1                                  Leiden University     Leiden
# 2                               Amsterdam University  Amsterdam
# 3                                École Polytechnique      Paris
# 4  École municipale de physique et de chimie indu...      Paris
#
#            country prizeAmount prizeAmountAdjusted
# 0          Germany    150782.0           8567159.0
# 1  the Netherlands    141847.0           8059489.0
# 2  the Netherlands    141847.0           8059489.0
# 3           France    141358.0           7795478.0
# 4           France    141358.0           7795478.0
#
# [5 rows x 22 columns]
